# %% [markdown]
# Observation: Large jumps in the rating of a player (hikaru, gothamchess)
# Outcome: Possible reasons
# - No bullet games were played in the skipped months — the next bullet game shows the updated bullet rating (possibly affected by global rating recalibration or inactivity decay).
# - Rating resets or re-calibrations — Chess.com occasionally normalizes ratings across all users; you’ll see a step change even without games.
#
# Unlikely but affects rating: Chess.com’s archive skipped some months — their API sometimes omits empty or partial archives, creating time gaps.

# %%
from utils.chesscom_downloader import ChesscomDownloader
import matplotlib.pyplot as plt

downloader = ChesscomDownloader(timeout=20.0, sleep_sec=0.2)
username = "gothamchess"
df = downloader.load_from_cache(username, timezone="Europe/Berlin")

# %%
mask = df["time_class"].astype(str).isin(["bullet"])
df = df[mask]
df
# Out:
#                        end_time     username    opponent_username  \
# 10    2017-03-14 17:47:52+00:00  GothamChess        bkoopmannnnnn
# 11    2017-03-14 17:50:21+00:00  GothamChess          abckerlchen
# 12    2017-03-14 17:51:47+00:00  GothamChess          Submariner7
# 13    2017-03-14 17:53:57+00:00  GothamChess          Submariner7
# 14    2017-03-14 17:56:26+00:00  GothamChess                Ainar
# ...                         ...          ...                  ...
# 29585 2025-10-02 02:58:53+00:00  GothamChess  Adelia-PermataPutri
# 29586 2025-10-02 03:02:30+00:00  GothamChess         TrimitziosP7
# 29587 2025-10-02 03:03:11+00:00  GothamChess              turkage
# 29588 2025-10-02 03:05:23+00:00  GothamChess         TrimitziosP7
# 29589 2025-10-02 13:55:50+00:00  GothamChess         PavlovDanila
#
#       user_played_as user_result user_result_simple opponent_result  \
# 10             white         win                win        resigned
# 11             black         win                win         timeout
# 12             white         win                win        resigned
# 13             black  checkmated               loss             win
# 14             black         win                win         timeout
# ...              ...         ...                ...             ...
# 29585          white     timeout               loss             win
# 29586          black    resigned               loss             win
# 29587          white         win                win        resigned
# 29588          black         win                win        resigned
# 29589          black         win                win      checkmated
#
#        user_rating  opponent_rating  rated  ...  \
# 10            1925             1665   True  ...
# 11            2040             1857   True  ...
# 12            2157             2072   True  ...
# 13            2050             2082   True  ...
# 14            2096             1868   True  ...
# ...            ...              ...    ...  ...
# 29585         2866             2776   True  ...
# 29586         2859             2897   True  ...
# 29587         2864             2718   True  ...
# 29588         2873             2888   True  ...
# 29589         2881             2852   True  ...
#
#                                         moves_normalized  \
# 10     1. b3 b6 2. Bb2 Bb7 3. e3 Nf6 4. f4 g6 5. Nf3 ...
# 11     1. f4 e5 2. fxe5 d6 3. exd6 Nf6 4. dxc7 Qxc7 5...
# 12     1. b3 e6 2. Bb2 d5 3. e3 Nf6 4. f4 c5 5. g4 Nc...
# 13     1. e4 e6 2. d3 d5 3. d4 dxe4 4. Nc3 Nf6 5. f3 ...
# 14     1. e4 e6 2. f4 d5 3. exd5 exd5 4. Nf3 Bd6 5. d...
# ...                                                  ...
# 29585  1. d4 h5 2. h4 g6 3. g3 Bg7 4. c3 Nf6 5. Bg2 d...
# 29586  1. b3 Na6 2. Bb2 c6 3. Nf3 f6 4. d4 Nh6 5. e4 ...
# 29587  1. h3 c6 2. a3 d5 3. g3 Nd7 4. b3 e5 5. Bg2 Bd...
# 29588  1. Nf3 g5 2. Nxg5 e5 3. d4 Be7 4. Ne4 d5 5. Ne...
# 29589  1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 e5 5. N...
#
#                                           moves_san_json  \
# 10     [b3, b6, Bb2, Bb7, e3, Nf6, f4, g6, Nf3, Bg7, ...
# 11     [f4, e5, fxe5, d6, exd6, Nf6, dxc7, Qxc7, Nf3,...
# 12     [b3, e6, Bb2, d5, e3, Nf6, f4, c5, g4, Nc6, g5...
# 13     [e4, e6, d3, d5, d4, dxe4, Nc3, Nf6, f3, c5, B...
# 14     [e4, e6, f4, d5, exd5, exd5, Nf3, Bd6, d4, Nf6...
# ...                                                  ...
# 29585  [d4, h5, h4, g6, g3, Bg7, c3, Nf6, Bg2, d6, Nh...
# 29586  [b3, Na6, Bb2, c6, Nf3, f6, d4, Nh6, e4, Nf7, ...
# 29587  [h3, c6, a3, d5, g3, Nd7, b3, e5, Bg2, Bd6, Bb...
# 29588  [Nf3, g5, Nxg5, e5, d4, Be7, Ne4, d5, Nec3, e4...
# 29589  [e4, c5, Nf3, Nc6, d4, cxd4, Nxd4, e5, Nb5, d6...
#
#                                              clocks_json n_plies opening_id  \
# 10     [0:01:00, 0:00:59.9, 0:00:59.9, 0:00:59.4, 0:0...      31      155.0
# 11     [0:01:00, 0:00:59.5, 0:00:59.2, 0:00:59.1, 0:0...      82      161.0
# 12     [0:01:00, 0:00:59.8, 0:00:59.5, 0:00:59.4, 0:0...      59      141.0
# 13     [0:01:00, 0:00:59.6, 0:00:59.6, 0:00:59.1, 0:0...      71     1502.0
# 14     [0:01:00, 0:01:00, 0:00:59.3, 0:00:59.4, 0:00:...      76     1506.0
# ...                                                  ...     ...        ...
# 29585  [0:00:46.6, 0:00:59.9, 0:00:45.8, 0:00:59.8, 0...      86      472.0
# 29586  [0:00:58.8, 0:00:58.1, 0:00:58.7, 0:00:57.6, 0...     109      141.0
# 29587  [0:00:59.7, 0:00:59.3, 0:00:59.1, 0:00:59.2, 0...      31       11.0
# 29588  [0:00:44.5, 0:00:58.4, 0:00:43.4, 0:00:58.2, 0...     142      196.0
# 29589  [0:00:57.4, 0:00:58.2, 0:00:56.7, 0:00:57.6, 0...     106     1261.0
#
#       matched_plies         opening_name               opening_variation  \
# 10                2  Nimzo-Larsen Attack           Symmetrical Variation
# 11                6         Bird Opening  From's Gambit, Langheld Gambit
# 12                1  Nimzo-Larsen Attack
# 13                3       French Defense            King's Indian Attack
# 14                3       French Defense        La Bourdonnais Variation
# ...             ...                  ...                             ...
# 29585             1    Queen's Pawn Game
# 29586             1  Nimzo-Larsen Attack
# 29587             1      Clemenz Opening
# 29588             2    Zukertort Opening                Herrstrom Gambit
# 29589            10     Sicilian Defense           Kalashnikov Variation
#
#                                    opening_fullname  \
# 10       Nimzo-Larsen Attack: Symmetrical Variation
# 11     Bird Opening: From's Gambit, Langheld Gambit
# 12                              Nimzo-Larsen Attack
# 13             French Defense: King's Indian Attack
# 14         French Defense: La Bourdonnais Variation
# ...                                             ...
# 29585                             Queen's Pawn Game
# 29586                           Nimzo-Larsen Attack
# 29587                               Clemenz Opening
# 29588           Zukertort Opening: Herrstrom Gambit
# 29589       Sicilian Defense: Kalashnikov Variation
#
#                                   opening_moves_san_json
# 10                                          ["b3", "b6"]
# 11             ["f4", "e5", "fxe5", "d6", "exd6", "Nf6"]
# 12                                                ["b3"]
# 13                                    ["e4", "e6", "d3"]
# 14                                    ["e4", "e6", "f4"]
# ...                                                  ...
# 29585                                             ["d4"]
# 29586                                             ["b3"]
# 29587                                             ["h3"]
# 29588                                      ["Nf3", "g5"]
# 29589  ["e4", "c5", "Nf3", "Nc6", "d4", "cxd4", "Nxd4...
#
# [10729 rows x 30 columns]

# %%
df = df[
    (df["end_time"].dt.year == 2025) &
    (df["end_time"].dt.month.isin([1, 2]))
]
df
# Out:
#                        end_time     username     opponent_username  \
# 28588 2025-01-22 00:27:43+00:00  GothamChess  ScacchiParlanoDaSoli
# 28589 2025-01-22 00:29:37+00:00  GothamChess  ScacchiParlanoDaSoli
# 28590 2025-01-22 00:31:40+00:00  GothamChess  ScacchiParlanoDaSoli
# 28591 2025-01-22 00:33:26+00:00  GothamChess  ScacchiParlanoDaSoli
# 28592 2025-01-22 00:34:41+00:00  GothamChess  ScacchiParlanoDaSoli
# 28593 2025-01-22 00:35:02+00:00  GothamChess  ScacchiParlanoDaSoli
# 28594 2025-01-22 00:36:31+00:00  GothamChess  ScacchiParlanoDaSoli
# 28595 2025-01-22 00:37:20+00:00  GothamChess  ScacchiParlanoDaSoli
# 28596 2025-01-22 00:39:29+00:00  GothamChess  ScacchiParlanoDaSoli
# 28597 2025-01-22 00:41:10+00:00  GothamChess  ScacchiParlanoDaSoli
# 28598 2025-01-22 00:46:31+00:00  GothamChess               Blindov
# 28599 2025-01-22 00:48:38+00:00  GothamChess               Blindov
# 28600 2025-01-22 00:50:17+00:00  GothamChess             DragonB70
# 28601 2025-01-22 00:52:25+00:00  GothamChess                zugzon
# 28602 2025-01-22 00:54:16+00:00  GothamChess                zugzon
# 28603 2025-01-22 00:55:32+00:00  GothamChess                zugzon
# 28604 2025-01-22 00:56:36+00:00  GothamChess               AGW2016
# 28605 2025-01-22 00:58:13+00:00  GothamChess               AGW2016
# 28606 2025-01-22 00:59:43+00:00  GothamChess               AGW2016
# 28619 2025-01-24 18:27:29+00:00  GothamChess        ant_chess_2019
# 28670 2025-02-22 01:53:59+00:00  GothamChess           joshuagarry
# 28671 2025-02-22 01:55:40+00:00  GothamChess           joshuagarry
# 28672 2025-02-22 01:57:15+00:00  GothamChess           joshuagarry
# 28673 2025-02-22 01:59:00+00:00  GothamChess           joshuagarry
# 28674 2025-02-22 01:59:36+00:00  GothamChess           joshuagarry
# 28675 2025-02-22 02:01:34+00:00  GothamChess           joshuagarry
# 28676 2025-02-22 02:04:18+00:00  GothamChess           joshuagarry
# 28677 2025-02-22 02:05:40+00:00  GothamChess           joshuagarry
#
#       user_played_as user_result user_result_simple opponent_result  \
# 28588          white         win                win         timeout
# 28589          black         win                win      checkmated
# 28590          white         win                win      checkmated
# 28591          black         win                win        resigned
# 28592          white         win                win        resigned
# 28593          black         win                win        resigned
# 28594          white         win                win        resigned
# 28595          black         win                win        resigned
# 28596          white         win                win         timeout
# 28597          black    resigned               loss             win
# 28598          black         win                win         timeout
# 28599          white         win                win         timeout
# 28600          black    resigned               loss             win
# 28601          white         win                win        resigned
# 28602          black         win                win        resigned
# 28603          white    resigned               loss             win
# 28604          black    resigned               loss             win
# 28605          white         win                win      checkmated
# 28606          black    resigned               loss             win
# 28619          black  checkmated               loss             win
# 28670          black         win                win         timeout
# 28671          white         win                win        resigned
# 28672          black         win                win        resigned
# 28673          white         win                win        resigned
# 28674          black         win                win        resigned
# 28675          white  checkmated               loss             win
# 28676          black         win                win        resigned
# 28677          white    resigned               loss             win
#
#        user_rating  opponent_rating  rated  ...  \
# 28588         2854             2816   True  ...
# 28589         2861             2809   True  ...
# 28590         2868             2802   True  ...
# 28591         2875             2795   True  ...
# 28592         2881             2789   True  ...
# 28593         2887             2783   True  ...
# 28594         2893             2777   True  ...
# 28595         2898             2772   True  ...
# 28596         2903             2767   True  ...
# 28597         2892             2778   True  ...
# 28598         2897             2764   True  ...
# 28599         2902             2759   True  ...
# 28600         2894             2919   True  ...
# 28601         2900             2799   True  ...
# 28602         2906             2793   True  ...
# 28603         2895             2803   True  ...
# 28604         2885             2819   True  ...
# 28605         2892             2812   True  ...
# 28606         2882             2822   True  ...
# 28619         2872             2800   True  ...
# 28670         2081             2179   True  ...
# 28671         2091             2169   True  ...
# 28672         2101             2159   True  ...
# 28673         2110             2150   True  ...
# 28674         2119             2141   True  ...
# 28675         2112             2148   True  ...
# 28676         2121             2139   True  ...
# 28677         2113             2147   True  ...
#
#                                         moves_normalized  \
# 28588  1. b3 d5 2. Bb2 Nc6 3. e3 e5 4. Bb5 Bd6 5. f4 ...
# 28589  1. e4 c6 2. Nc3 d5 3. d4 dxe4 4. Nxe4 Nf6 5. N...
# 28590  1. g3 h5 2. h3 h4 3. g4 e5 4. Bg2 d5 5. c4 c6 ...
# 28591  1. e4 e6 2. Nc3 d5 3. d4 dxe4 4. Nxe4 Nf6 5. N...
# 28592  1. b3 a5 2. Bb2 a4 3. Nf3 Nc6 4. bxa4 Rxa4 5. ...
# 28593  1. e4 d5 2. Nc3 dxe4 3. Nxe4 h6 4. Ng5 hxg5 5....
# 28594  1. Nf3 g5 2. Nxg5 e5 3. d4 Be7 4. h4 h6 5. Nxf...
# 28595  1. e4 e6 2. Nc3 d5 3. d4 dxe4 4. Nxe4 h6 5. Nf...
# 28596  1. d4 e5 2. dxe5 d6 3. exd6 Bxd6 4. Nc3 Nf6 5....
# 28597  1. d4 c5 2. d5 d6 3. c4 a6 4. Nc3 g6 5. e4 Bg7...
# 28598  1. e4 e6 2. d4 d5 3. e5 c5 4. c3 Ne7 5. Nf3 Ne...
# 28599  1. b3 e5 2. Bb2 Nc6 3. e3 Nf6 4. Nf3 Bd6 5. Na...
# 28600  1. Nf3 g5 2. g3 g4 3. Nd4 c5 4. Nb3 b6 5. Bg2 ...
# 28601  1. d4 d5 2. Bg5 Nf6 3. Bxf6 exf6 4. e3 Bd6 5. ...
# 28602  1. e4 d5 2. exd5 Qxd5 3. d4 e5 4. c3 exd4 5. c...
# 28603  1. Nf3 c5 2. b4 cxb4 3. a3 Nf6 4. axb4 g6 5. B...
# 28604  1. d4 e5 2. dxe5 Nc6 3. Nf3 Qe7 4. Nc3 Nxe5 5....
# 28605  1. Na3 Na6 2. c3 c6 3. Nc2 Nc7 4. d4 d5 5. Nf3...
# 28606  1. d4 d5 2. Nf3 Nf6 3. Bf4 e6 4. e3 Bd6 5. Nbd...
# 28619  1. e4 e6 2. d4 d5 3. Nd2 dxe4 4. Nxe4 Nf6 5. N...
# 28670  1. Nf3 g6 2. Ng3 f5 3. e4 f4 4. Ne2 e5 5. d4 d...
# 28671  1. d4 Ng6 2. c3 Nf6 3. g3 d5 4. Bg2 Bf5 5. Nd3...
# 28672  1. Nf3 f6 2. Ng3 Bf7 3. d3 e5 4. Bc3 d5 5. e4 ...
# 28673  1. a3 g6 2. c3 c5 3. Ba2 Nb6 4. Nc2 d5 5. h4 e...
# 28674  1. c3 e5 2. g4 c6 3. h3 d5 4. Bh2 g6 5. e4 Ne7...
# 28675  1. Nf3 Nf6 2. O-O Ne6 3. d4 O-O 4. c4 c6 5. Bc...
# 28676  1. Nab3 g6 2. d4 Qg7 3. Bc3 O-O 4. d5 f6 5. Nd...
# 28677  1. g3 b6 2. Bg2 Bxg2+ 3. Kxg2 g6 4. c4 Nf6 5. ...
#
#                                           moves_san_json  \
# 28588  [b3, d5, Bb2, Nc6, e3, e5, Bb5, Bd6, f4, f6, N...
# 28589  [e4, c6, Nc3, d5, d4, dxe4, Nxe4, Nf6, Ng5, Bf...
# 28590  [g3, h5, h3, h4, g4, e5, Bg2, d5, c4, c6, d4, ...
# 28591  [e4, e6, Nc3, d5, d4, dxe4, Nxe4, Nf6, Ng5, h6...
# 28592  [b3, a5, Bb2, a4, Nf3, Nc6, bxa4, Rxa4, e3, d6...
# 28593  [e4, d5, Nc3, dxe4, Nxe4, h6, Ng5, hxg5, d4, g...
# 28594  [Nf3, g5, Nxg5, e5, d4, Be7, h4, h6, Nxf7, Kxf...
# 28595  [e4, e6, Nc3, d5, d4, dxe4, Nxe4, h6, Nf3, Nf6...
# 28596  [d4, e5, dxe5, d6, exd6, Bxd6, Nc3, Nf6, Nf3, ...
# 28597  [d4, c5, d5, d6, c4, a6, Nc3, g6, e4, Bg7, h4,...
# 28598  [e4, e6, d4, d5, e5, c5, c3, Ne7, Nf3, Nec6, N...
# 28599  [b3, e5, Bb2, Nc6, e3, Nf6, Nf3, Bd6, Na3, O-O...
# 28600  [Nf3, g5, g3, g4, Nd4, c5, Nb3, b6, Bg2, Nc6, ...
# 28601  [d4, d5, Bg5, Nf6, Bxf6, exf6, e3, Bd6, c4, dx...
# 28602  [e4, d5, exd5, Qxd5, d4, e5, c3, exd4, cxd4, B...
# 28603  [Nf3, c5, b4, cxb4, a3, Nf6, axb4, g6, Bb2, Bg...
# 28604  [d4, e5, dxe5, Nc6, Nf3, Qe7, Nc3, Nxe5, Nxe5,...
# 28605  [Na3, Na6, c3, c6, Nc2, Nc7, d4, d5, Nf3, Nf6,...
# 28606  [d4, d5, Nf3, Nf6, Bf4, e6, e3, Bd6, Nbd2, Bxf...
# 28619  [e4, e6, d4, d5, Nd2, dxe4, Nxe4, Nf6, Nxf6+, ...
# 28670  [Nf3, g6, Ng3, f5, e4, f4, Ne2, e5, d4, d6, dx...
# 28671  [d4, Ng6, c3, Nf6, g3, d5, Bg2, Bf5, Nd3, e6, ...
# 28672  [Nf3, f6, Ng3, Bf7, d3, e5, Bc3, d5, e4, d4, B...
# 28673  [a3, g6, c3, c5, Ba2, Nb6, Nc2, d5, h4, e6, g4...
# 28674  [c3, e5, g4, c6, h3, d5, Bh2, g6, e4, Ne7, exd...
# 28675  [Nf3, Nf6, O-O, Ne6, d4, O-O, c4, c6, Bc3, d5,...
# 28676  [Nab3, g6, d4, Qg7, Bc3, O-O, d5, f6, Nd3, Nab...
# 28677  [g3, b6, Bg2, Bxg2+, Kxg2, g6, c4, Nf6, d4, Bg...
#
#                                              clocks_json n_plies opening_id  \
# 28588  [0:00:57.8, 0:00:59.9, 0:00:57, 0:00:59.5, 0:0...     169      142.0
# 28589  [0:01:00, 0:00:59.2, 0:00:59.9, 0:00:58.8, 0:0...     112     1005.0
# 28590  [0:01:00, 0:01:00, 0:00:59.3, 0:00:59.9, 0:00:...     123       65.0
# 28591  [0:01:00, 0:01:00, 0:00:59.9, 0:00:59.6, 0:00:...      62     1514.0
# 28592  [0:01:00, 0:01:00, 0:00:59.2, 0:00:59.9, 0:00:...      55      141.0
# 28593  [0:01:00, 0:01:00, 0:00:59.9, 0:00:59.3, 0:00:...      23      824.0
# 28594  [0:01:00, 0:01:00, 0:00:59.2, 0:00:59.7, 0:00:...      54      196.0
# 28595  [0:01:00, 0:01:00, 0:00:59.8, 0:00:59.7, 0:00:...      48     1514.0
# 28596  [0:01:00, 0:01:00, 0:00:59.1, 0:00:59.9, 0:00:...     143      446.0
# 28597  [0:01:00, 0:00:59.9, 0:00:57.9, 0:00:59.4, 0:0...      69      503.0
# 28598  [0:01:00, 0:00:54.4, 0:00:59.3, 0:00:54.1, 0:0...     128     1536.0
# 28599  [0:01:00, 0:01:00, 0:00:59.9, 0:00:58.8, 0:00:...     119      149.0
# 28600  [0:01:00, 0:01:00, 0:00:59.9, 0:00:59.9, 0:00:...      39      196.0
# 28601  [0:01:00, 0:00:59, 0:00:59.5, 0:00:57.8, 0:00:...     117     2750.0
# 28602  [0:00:59.9, 0:00:56.9, 0:00:58.6, 0:00:56.8, 0...      92      846.0
# 28603  [0:01:00, 0:00:59.9, 0:00:58.9, 0:00:59, 0:00:...      62      206.0
# 28604  [0:00:59.9, 0:00:58.3, 0:00:58.6, 0:00:58, 0:0...      61      447.0
# 28605  [0:01:00, 0:00:59.8, 0:00:59.9, 0:00:59.2, 0:0...      85       94.0
# 28606  [0:01:00, 0:01:00, 0:00:59.9, 0:00:59.2, 0:00:...      81     2774.0
# 28619  [0:01:00, 0:00:53.3, 0:00:59.2, 0:00:52.8, 0:0...     137     1555.0
# 28670  [0:00:59.4, 0:00:59, 0:00:58.5, 0:00:58.5, 0:0...      90      197.0
# 28671  [0:00:59.1, 0:00:59.2, 0:00:58.6, 0:00:58.8, 0...      75      472.0
# 28672  [0:01:00, 0:00:59.9, 0:00:59.7, 0:00:59.4, 0:0...      96      190.0
# 28673  [0:00:59.7, 0:00:59.2, 0:00:57.9, 0:00:58.2, 0...     105        4.0
# 28674  [0:00:59.1, 0:00:58.5, 0:00:58.4, 0:00:57.3, 0...      26       93.0
# 28675  [0:01:00, 0:01:00, 0:00:59.6, 0:00:59.6, 0:00:...     120      220.0
# 28676  [0:01:00, 0:00:55.5, 0:00:59.3, 0:00:55.2, 0:0...      68        NaN
# 28677  [0:01:00, 0:01:00, 0:00:59.6, 0:00:58.5, 0:00:...      88       37.0
#
#       matched_plies          opening_name         opening_variation  \
# 28588             2   Nimzo-Larsen Attack       Classical Variation
# 28589             4     Caro-Kann Defense
# 28590             2  Lasker Simul Special
# 28591             3        French Defense            Queen's Knight
# 28592             1   Nimzo-Larsen Attack
# 28593             2  Scandinavian Defense
# 28594             2     Zukertort Opening          Herrstrom Gambit
# 28595             3        French Defense            Queen's Knight
# 28596             4        Englund Gambit  Hartlaub-Charlick Gambit
# 28597             4        Benoni Defense                Old Benoni
# 28598             7        French Defense         Advance Variation
# 28599             5   Nimzo-Larsen Attack          Modern Variation
# 28600             2     Zukertort Opening          Herrstrom Gambit
# 28601             3     Queen's Pawn Game           Levitsky Attack
# 28602             4  Scandinavian Defense   Mieses-Kotroc Variation
# 28603             2     Zukertort Opening       Sicilian Invitation
# 28604             6        Englund Gambit                 Main Line
# 28605             1         Sodium Attack
# 28606             5     Queen's Pawn Game             London System
# 28619             5        French Defense        Tarrasch Variation
# 28670             2     Zukertort Opening       Kingside Fianchetto
# 28671             1     Queen's Pawn Game
# 28672             2     Zukertort Opening            Arctic Defense
# 28673             1   Anderssen's Opening
# 28674             1     Saragossa Opening
# 28675             2     Zukertort Opening
# 28676             0                   NaN                       NaN
# 28677             1     Hungarian Opening
#
#                                     opening_fullname  \
# 28588       Nimzo-Larsen Attack: Classical Variation
# 28589                              Caro-Kann Defense
# 28590                           Lasker Simul Special
# 28591                 French Defense: Queen's Knight
# 28592                            Nimzo-Larsen Attack
# 28593                           Scandinavian Defense
# 28594            Zukertort Opening: Herrstrom Gambit
# 28595                 French Defense: Queen's Knight
# 28596       Englund Gambit: Hartlaub-Charlick Gambit
# 28597                     Benoni Defense: Old Benoni
# 28598              French Defense: Advance Variation
# 28599          Nimzo-Larsen Attack: Modern Variation
# 28600            Zukertort Opening: Herrstrom Gambit
# 28601             Queen's Pawn Game: Levitsky Attack
# 28602  Scandinavian Defense: Mieses-Kotroc Variation
# 28603         Zukertort Opening: Sicilian Invitation
# 28604                      Englund Gambit: Main Line
# 28605                                  Sodium Attack
# 28606               Queen's Pawn Game: London System
# 28619             French Defense: Tarrasch Variation
# 28670         Zukertort Opening: Kingside Fianchetto
# 28671                              Queen's Pawn Game
# 28672              Zukertort Opening: Arctic Defense
# 28673                            Anderssen's Opening
# 28674                              Saragossa Opening
# 28675                              Zukertort Opening
# 28676                                            NaN
# 28677                              Hungarian Opening
#
#                            opening_moves_san_json
# 28588                                ["b3", "d5"]
# 28589                   ["e4", "c6", "Nc3", "d5"]
# 28590                                ["g3", "h5"]
# 28591                         ["e4", "e6", "Nc3"]
# 28592                                      ["b3"]
# 28593                                ["e4", "d5"]
# 28594                               ["Nf3", "g5"]
# 28595                         ["e4", "e6", "Nc3"]
# 28596                  ["d4", "e5", "dxe5", "d6"]
# 28597                    ["d4", "c5", "d5", "d6"]
# 28598  ["e4", "e6", "d4", "d5", "e5", "c5", "c3"]
# 28599            ["b3", "e5", "Bb2", "Nc6", "e3"]
# 28600                               ["Nf3", "g5"]
# 28601                         ["d4", "d5", "Bg5"]
# 28602                ["e4", "d5", "exd5", "Qxd5"]
# 28603                               ["Nf3", "c5"]
# 28604   ["d4", "e5", "dxe5", "Nc6", "Nf3", "Qe7"]
# 28605                                     ["Na3"]
# 28606           ["d4", "d5", "Nf3", "Nf6", "Bf4"]
# 28619             ["e4", "e6", "d4", "d5", "Nd2"]
# 28670                               ["Nf3", "g6"]
# 28671                                      ["d4"]
# 28672                               ["Nf3", "f6"]
# 28673                                      ["a3"]
# 28674                                      ["c3"]
# 28675                              ["Nf3", "Nf6"]
# 28676                                         NaN
# 28677                                      ["g3"]
#
# [28 rows x 30 columns]
